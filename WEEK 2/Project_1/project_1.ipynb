# %% [markdown]
# A)
# START
#
# SET total = 0
#
# INPUT number_of_items
#
# FOR each item
#  INPUT item_price
#  total = total + item_price
#  END FOR
#
# PRINT 'TOTAL AMOUNT',total
#
# INPUT payment_method
#  IF payment successful
#   PRINT 'payment successful'
#
#   ELSE
#   PRINT 'payment declined'
#
#   END IF
#   PRINT 'Thanks for shopping with us'
#
#   END

# %% [markdown]
# C)
# START
#
# INPUT Name_1
# INPUT Age_1
# INPUT Name_2
# INPUT Age_2
#
# STORE Age_1 in temp
#
# SET Age_1 = Age_2
# SET Temp = Age_2
# PRINT Name_1 and new Age_1
# PRINT Name_2 and new Age_2
#
# END
