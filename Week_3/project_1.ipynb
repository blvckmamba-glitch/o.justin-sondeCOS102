# %%
import tkinter as tk
from tkinter import messagebox
import pandas as pd


# Load dataset
data = pd.read_csv("GIG-logistics.csv" _read()

root = tk.Tk()
root.title("GIG Logistics Employee Verification")

# Labels and Entry fields
tk.Label(root, text="Enter Employee Name:").grid(row=0, column=0, padx=10, pady=5)
name_entry = tk.Entry(root)
name_entry.grid(row=0, column=1, padx=10, pady=5)


tk.Label(root, text="Enter Department:").grid(row=1, column=0, padx=10, pady=5)
dept_entry = tk.Entry(root)
dept_entry.grid(row=1, column=1, padx=10, pady=5)

# Function to verify employee
def verify_employee():
    name = name_entry.get().strip()
    dept = dept_entry.get().strip()

    # Check if employee exists
    employee = data[(data['Name'].str.lower() == name.lower()) & 
                    (data['Department'].str.lower() == dept.lower())]

    if not employee.empty:
        # Welcome message
        messagebox.showinfo("Welcome", f"Welcome {name} to {dept} Department!")

        # Show other members of department
        dept_members = data[data['Department'].str.lower() == dept.lower()]['Name'].tolist()
        dept_members.remove(name)  # remove current employee
        members_text = "\n".join(dept_members) if dept_members else "No other members."
        
        result_label.config(text=f"Other members in {dept}:\n{members_text}")
    else:
        messagebox.showwarning("Not Found", "Employee does not exist.")
        result_label.config(text="")

# Verify button
verify_btn = tk.Button(root, text="Verify", command=verify_employee)
verify_btn.grid(row=2, column=0, columnspan=2, pady=10)

# Result label
result_label = tk.Label(root, text="", justify="left")
result_label.grid(row=3, column=0, columnspan=2, padx=10, pady=10)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[28], line 7
#       3 import pandas as pd
#       6 # Load dataset
# ----> 7 data = pd.read_csv("GIG-logistics.csv" )
#       9 root = tk.Tk()
#      10 root.title("GIG Logistics Employee Verification")
#
# ...
