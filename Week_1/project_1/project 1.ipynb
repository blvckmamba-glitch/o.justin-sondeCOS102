# %%
def simple_interest():
    P = float(input("Enter your principal (P): "))
    R = float(input("Enter the annual interest rate (%) (R): "))
    T = float(input("Enter the time in years (T): "))
    A = P * (1 + (R/100) * T)
    print(f"Simple Interest Total Amount: {A:.2f}\n")

def compound_interest():
    P = float(input("Enter your principal (P): "))
    R = float(input("Enter the annual interest rate (%) (R): "))
    T = float(input("Enter the time in years (T): "))
    n = int(input("Enter number of compounding periods per year (n): "))
    A = P * (1 + (R/(100*n)))**(n*T)
    print(f"Compound Interest Total Amount: {A:.2f}\n")

def annuity_plan():
    PMT = float(input("Enter your periodic payment (PMT): "))
    R = float(input("Enter the annual interest rate (%) (R): "))
    T = float(input("Enter the time in years (T): "))
    n = int(input("Enter number of compounding periods per year (n): "))
    A = PMT * (((1 + (R/(100*n)))**(n*T) - 1) / (R/(100*n)))
    print(f"Annuity plan: {A:.2f}\n")

def main():
    while True:
        print("Choose calculation type:")
        print("1. Simple Interest")
        print("2. Compound Interest")
        print("3. Future Value of Annuity")
        print("4. Exit")
        choice = input("Enter your choice (1-4): ")

        if choice == "1":
            simple_interest()
        elif choice == "2":
            compound_interest()
        elif choice == "3":
            annuity_future_value()
        elif choice == "4":
            print("Exiting program.")
            break
        else:
            print("Invalid choice. Please enter 1-4.\n")

if __name__ == "__main__":
    main()
# Out:
# Choose calculation type:
# 1. Simple Interest
# 2. Compound Interest
# 3. Future Value of Annuity
# 4. Exit
# Enter your choice (1-4):  3
# Enter your periodic payment (PMT):  3
# Enter the annual interest rate (%) (R):  3
# Enter the time in years (T):  3
# Enter number of compounding periods per year (n):  3
# Future Value of Annuity: 28.11
#
# Choose calculation type:
# 1. Simple Interest
# 2. Compound Interest
# 3. Future Value of Annuity
# 4. Exit
